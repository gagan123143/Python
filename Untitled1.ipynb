# %%
import pandas as pd
data={
    "name":["samay","ravi"],
    "marrks":[45,67]}
c=pd.DataFrame(data)
print(c)
# Out:
#     name  marrks
# 0  samay      45
# 1   ravi      67

# %%
data=[
    ["samay",45],
    ["ravi",78],
    ["ommu",67]]
d=pd.DataFrame(data,columns=["name","marks"],index=[1,2,3])
print(d)
# Out:
#     name  marks
# 1  samay     45
# 2   ravi     78
# 3   ommu     67

# %%
import numpy as np
arr=np.array([["pres","past","p_pasticful"],["do","did","done"]])
d=pd.DataFrame(arr,columns=["a","b","c"],)
print(d)
# Out:
#       a     b            c
# 0  pres  past  p_pasticful
# 1    do   did         done

# %%
import pandas as pd
r_d=pd.read_excel("data.xlsx")

# %%
r_d
# Out:
#    name   roll_no gade
# 0  samay       23    c
# 1   ravi       34    a
# 2   hari        2    c
# 3    jnn       67    d
# 4   jjio       45    d
# 5   njfj       55    c
