# %%
import matplotlib.pyplot as plt

# %%
plt.plot([1, 2, 3], [4, 5, 6])
plt.show()

# %%
plt.plot(0,0)
plt.show()

# %%
years = [1990, 1992, 1994, 1996, 1998, 2000, 2003, 2005, 2007, 2010]
runs = [500, 700, 1100, 1500, 1800, 1200, 1700, 1300, 900, 1500]
plt.plot(years,runs)
plt.show()

# %%
plt.plot(years, runs)
plt.xlabel("Year")
plt.ylabel("Runs Scored")
plt.title("Sachin Tendulkar's Yearly Runs")
plt.show()

# %%
kohli = [0, 0, 500, 800, 1100, 1300, 1500, 1800, 1900, 2100]
sehwag = [2000, 300, 800, 1200, 1500, 1700, 1600, 1400, 1000, 0]
plt.plot(years, kohli, color='black',label="Virat Kohli")
plt.plot(years, sehwag, color='pink', label="Virender Sehwag")
plt.xlabel("Year")
plt.ylabel("Runs Scored")
plt.title("Performance Comparison")
plt.legend()
plt.show()

# %%
kohli = [0, 0, 500, 800, 1100, 1300, 1500, 1800, 1900, 2100]
sehwag = [2000, 300, 800, 1200, 1500, 1700, 1600, 1400, 1000, 0]
sachin = [500, 700, 1100, 1500, 1800, 1200, 1700, 1300, 900, 1500]
plt.plot(years, kohli, label="Virat Kohli")
plt.plot(years, sehwag, label="Virender Sehwag")
plt.plot(years,sachin,  label="Sachin Tendulkar")
plt.xlabel("Year")
plt.ylabel("Runs Scored")
plt.title("Performance Comparison")
plt.legend()
plt.show()

# %%
plt.plot(years, kohli, color='orange', linestyle='--', label="Kohli")
plt.plot(years, sehwag, color='green', linestyle='-.', label="Sehwag")
plt.plot(years, runs, color='blue', label="Tendulkar")
plt.legend()

# %%
plt.plot(years, kohli, linewidth=3, label="Kohli")
plt.plot(years, sehwag, linewidth=2, label="Sehwag")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
plt.plot(years, kohli, 'ro--', label="Kohli") # red circles with dashed lines
plt.plot(years, sehwag, 'b^:', label="Sehwag") # green triangles dotted
plt.legend()

# %%
years = [1990, 1992, 1994, 1996, 1998, 2000, 2003, 2005, 2007, 2010]

# %%
kohli = [0, 0, 500, 800, 1100, 1300, 1500, 1800, 1900, 2100]
sehwag = [0, 300, 800, 1200, 1500, 1700, 1600, 1400, 1000, 0]
plt.plot(years, kohli, color='black',label="Virat Kohli")
plt.plot(years, sehwag, color='pink', label="Virender Sehwag")
plt.xlabel("Year")
plt.ylabel("Runs Scored")
plt.title("Performance Comparison")
plt.legend()
plt.show()

# %%
plt.plot([1,2],[2,3])
plt.plot([5,6],[7,8])
plt.xlabel('x----->')
plt.ylabel('y------>')
# Out:
# Text(0, 0.5, 'y------>')

# %%
years = [1990, 1992, 1994, 1996, 1998, 2000, 2003, 2005, 2007, 2010]
runs = [500, 700, 1100, 1500, 1800, 1200, 1700, 1300, 900, 1500]

# %%
plt.plot(years,runs,label='sachin')
plt.xlabel('years')
plt.ylabel('Runs')
plt.title("sachin's score over the year")
plt.legend()

# %%
kohli = [0, 0, 500, 800, 1100, 1300, 1500, 1800, 1900, 2100]
sehwag = [0, 300, 800, 1200, 1500, 1700, 1600, 1400, 1000, 0]

# %%
plt.plot(years,kohli,color='green',label="kohli")
plt.plot(years,sehwag,label="sehwag")
plt.xlabel('years')
plt.ylabel('runs')
plt.title('kohli vs sehwag')
plt.grid("true")
plt.legend()

# %%
import pandas as pd
data={
    "years":[2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021],
    "runs":[95,465,111,312,319,360,395,513,687,216,480,442,454,313]}

# %%
import numpy as np
arr=np.array([
    [2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021],
    [95,465,111,312,319,360,395,513,687,216,480,442,454,313]])
df=pd.DataFrame(arr.T,columns=["years","runs"])
df
# Out:
#     years  runs
# 0    2008    95
# 1    2009   465
# 2    2010   111
# 3    2011   312
# 4    2012   319
# 5    2013   360
# 6    2014   395
# 7    2015   513
# 8    2016   687
# 9    2017   216
# 10   2018   480
# 11   2019   442
# 12   2020   454
# 13   2021   313

# %%
arr = np.array([
    [2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021],
    [95, 465, 111, 312, 319, 360, 395, 513, 687, 216, 480, 442, 454, 313]
    ])

# Transpose the array so each row becomes a column
df = pd.DataFrame(arr.T, columns=["years", "runs"])
x=df['years']
y=df['runs']
print(df)
# Out:
#     years  runs
# 0    2008    95
# 1    2009   465
# 2    2010   111
# 3    2011   312
# 4    2012   319
# 5    2013   360
# 6    2014   395
# 7    2015   513
# 8    2016   687
# 9    2017   216
# 10   2018   480
# 11   2019   442
# 12   2020   454
# 13   2021   313

# %%
import seaborn as sns
plt.plot(x,y)

# %%
years=[2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021]
ABD=[95,465,111,312,319,360,395,513,687,216,480,442,454,313]
plt.plot(years,ABD,color='red',label="ABD")
plt.xlabel('years')
plt.ylabel('runs')
plt.grid('true')
plt.tight_layout()
plt.title("ABD's score in ipl")
plt.legend()

# %%
RoHit=[404,362,404,372,433,538,390,482,489,333,286,405,332,381]
plt.plot(years,RoHit,color='#0938B0',label='RoHit')
plt.xlabel("years")
plt.ylabel("runs")
plt.legend()
plt.tight_layout()
plt.grid('true')
plt.title("RoHit's Score Over The Yr in IPL")
# Out:
# Text(0.5, 1.0, "RoHit's Score Over The Yr in IPL")

# %%
Virat=[165,246,307,	557,364,634,359,505,973,308,530,464,466,405]
plt.plot(years,Virat,color='#42F007',label='Virat')
plt.xlabel("years")
plt.ylabel("runs")
plt.title("VIrat's score over the year")
plt.legend()
plt.grid('true')

# %%
plt.plot(years,ABD,color='red',label="ABD")
plt.plot(years,RoHit,color='#0938B0',label='RoHit')
plt.plot(years,Virat,color='#42F007',label="Kohli")
plt.xlabel("years")
plt.ylabel("runs")
plt.legend()
plt.tight_layout()
plt.grid('true')
plt.title("ABD vs RoHit vs Virat")
# Out:
# Text(0.5, 1.0, 'ABD vs RoHit vs Virat')

# %%
plt.plot(years,ABD,'rv--',label="ABD")
plt.plot(years,RoHit,'g^-',label='RoHit')
plt.plot(years,Virat,'bx-.',label="Kohli")
plt.xlabel("years")
plt.ylabel("runs")
plt.legend()
plt.grid('true')
plt.title("ABD vs RoHit vs Virat")
# Out:
# Text(0.5, 1.0, 'ABD vs RoHit vs Virat')

# %%
print(plt.style.available)
# Out:
# ['Solarize_Light2', '_classic_test_patch', '_mpl-gallery', '_mpl-gallery-nogrid', 'bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'petroff10', 'seaborn-v0_8', 'seaborn-v0_8-bright', 'seaborn-v0_8-colorblind', 'seaborn-v0_8-dark', 'seaborn-v0_8-dark-palette', 'seaborn-v0_8-darkgrid', 'seaborn-v0_8-deep', 'seaborn-v0_8-muted', 'seaborn-v0_8-notebook', 'seaborn-v0_8-paper', 'seaborn-v0_8-pastel', 'seaborn-v0_8-poster', 'seaborn-v0_8-talk', 'seaborn-v0_8-ticks', 'seaborn-v0_8-white', 'seaborn-v0_8-whitegrid', 'tableau-colorblind10']

# %%
import numpy as np
years = [1990, 1992, 1994, 1996, 1998, 2000, 2003, 2005, 2007, 2010]
sachin = [500, 700, 1100, 1500, 1800, 1200, 1700, 1300, 900, 1500]
sehwag = [30, 200, 900, 1400, 1600, 1800, 1500, 1100, 800, 0]
kohli = [49, 0, 500, 800, 1100, 1300, 1500, 1800, 1900, 2100]

x=np.arange(len(years))

width=0.25
plt.bar(x-width,sachin,width=width,label='sachin')
plt.bar(x,sehwag,width=width,label='sehwag')
plt.bar(x+width,kohli,width=width,label='kohli')
plt.xlabel('years')
plt.ylabel('runs')
plt.xticks(x,years)
plt.title('sachin vs sehwag vs kohli')
plt.legend()
plt.tight_layout()

# %%
import matplotlib.pyplot as plt
import numpy as np
for i in range(50):
    plt.plot(np.random.rand(100), linewidth=1)
plt.title("Too Much Data Can Be Confusing!")
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
plt.style.use("ggplot")
labels=["sachin","rrr","rttt"]
runs=[34,56,89]
colors = ['#ff9999','#66b3ff','#99ff99','#ffcc99']
plt.pie(runs,labels=labels,colors=colors)
# Out:
# ([<matplotlib.patches.Wedge at 0x246f8f84ec0>,
#   <matplotlib.patches.Wedge at 0x246fc839590>,
#   <matplotlib.patches.Wedge at 0x246fc839810>],
#  [Text(0.9098971101987365, 0.6181320642484003, 'sachin'),
#   Text(-0.6260930856252606, 0.9044376419257663, 'rrr'),
#   Text(0.00965317137799633, -1.0999576429491944, 'rttt')])

# %%
labels=["sachin","rrr","rttt"]
runs=[34,56,89]
colors = ['#ff9999','#66b3ff','#99ff99','#ffcc99']
explode=[0.2,0.1,0.3]
plt.pie(runs,labels=labels,colors=colors,explode=explode,wedgeprops={'edgecolor':'black','linewidth':2,'linestyle':':'}
      )
# Out:
# ([<matplotlib.patches.Wedge at 0x246fc875090>,
#   <matplotlib.patches.Wedge at 0x246fc875310>,
#   <matplotlib.patches.Wedge at 0x246fc875590>],
#  [Text(1.0753329484166887, 0.7305197122935639, 'sachin'),
#   Text(-0.6830106388639205, 0.9866592457371995, 'rrr'),
#   Text(0.012285854481086239, -1.3999460910262473, 'rttt')])

# %%
labels=["sachin","rrr","rttt"]
runs=[34,56,89]
colors = ['#ff9999','#66b3ff','#99ff99','#ffcc99']

plt.pie(runs,labels=labels,colors=colors,shadow='true',wedgeprops={'edgecolor':'black','linewidth':2,'linestyle':':'}
      )
# Out:
# ([<matplotlib.patches.Wedge at 0x246fc8accd0>,
#   <matplotlib.patches.Wedge at 0x246fc8acf50>,
#   <matplotlib.patches.Wedge at 0x246fc8ad310>],
#  [Text(0.9098971101987365, 0.6181320642484003, 'sachin'),
#   Text(-0.6260930856252606, 0.9044376419257663, 'rrr'),
#   Text(0.00965317137799633, -1.0999576429491944, 'rttt')])

# %%
labels=["sachin","rrr","rttt"]
runs=[34,56,89]
colors = ['#ff9999','#66b3ff','#99ff99','#ffcc99']

plt.pie(runs,labels=labels,colors=colors,shadow='true',autopct='1%.1f%%',startangle=90,wedgeprops={'edgecolor':'black','linewidth':2,'linestyle':':'}
      )
# Out:
# ([<matplotlib.patches.Wedge at 0x246fc584a50>,
#   <matplotlib.patches.Wedge at 0x246fc584f50>,
#   <matplotlib.patches.Wedge at 0x246fc585450>],
#  [Text(-0.6181322124894475, 0.9098970094922285, 'sachin'),
#   Text(-0.9044376891944764, -0.6260930173421164, 'rrr'),
#   Text(1.0999576459794298, 0.009652826083165915, 'rttt')],
#  [Text(-0.33716302499424405, 0.4963074597230337, '119.0%'),
#   Text(-0.49332964865153256, -0.3415052821866089, '131.3%'),
#   Text(0.5999768978069616, 0.005265177863545044, '149.7%')])

# %%
languages = ['Python', 'Java', 'C++', 'JavaScript', 'C#', 'Ruby', 'Go', 'Rust',
'Swift', 'PHP']
usage = [30, 20, 10, 10, 7, 5, 4, 3, 2, 1]
plt.pie(usage, labels=languages, autopct='%1.1f%%', startangle=90)
# Out:
# ([<matplotlib.patches.Wedge at 0x246fc5cccd0>,
#   <matplotlib.patches.Wedge at 0x246fc5cd090>,
#   <matplotlib.patches.Wedge at 0x246fc5cd450>,
#   <matplotlib.patches.Wedge at 0x246fc5cd810>,
#   <matplotlib.patches.Wedge at 0x246fc5cdbd0>,
#   <matplotlib.patches.Wedge at 0x246fc5cdf90>,
#   <matplotlib.patches.Wedge at 0x246fc5ce350>,
#   <matplotlib.patches.Wedge at 0x246fc5ce710>,
#   <matplotlib.patches.Wedge at 0x246fc5cead0>,
#   <matplotlib.patches.Wedge at 0x246fc5cee90>],
#  [Text(-0.9398614573727001, 0.5715421602517738, 'Python'),
#   Text(-0.4382411041767217, -1.00893247277009, 'Java'),
#   Text(0.6343486831711304, -0.8986666501874059, 'C++'),
#   Text(1.0592090841748596, -0.29677620524808807, 'JavaScript'),
#   Text(1.0484590470755086, 0.33276662483716246, 'C#'),
#   Text(0.8290839603449083, 0.7229244681837811, 'Ruby'),
#   Text(0.5715414768025876, 0.9398618729868328, 'Go'),
#   Text(0.33276458755135785, 1.0484596936801027, 'Rust'),
#   Text(0.14978239654094422, 1.0897546667422222, 'Swift'),
#   Text(0.03755326973065077, 1.0993587912654073, 'PHP')],
#  [Text(-0.5126517040214728, 0.3117502692282403, '32.6%'),
#   Text(-0.2390406022782118, -0.5503268033291399, '21.7%'),
#   Text(0.3460083726387983, -0.49018180919313037, '10.9%'),
#   Text(0.5777504095499234, -0.16187793013532073, '10.9%'),
#   Text(0.5718867529502774, 0.1815090680929977, '7.6%'),
#   Text(0.4522276147335863, 0.3943224371911533, '5.4%'),
#   Text(0.311749896437775, 0.5126519307200905, '4.3%'),
#   Text(0.18150795684619517, 0.5718871056436923, '3.3%'),
#   Text(0.08169948902233319, 0.5944116364048484, '2.2%'),
#   Text(0.020483601671264052, 0.5996502497811311, '1.1%')])

# %%
import matplotlib.pyplot as plt
days = [1, 2, 3, 4, 5, 6, 7] # Days of the week
studying = [3, 4, 3, 5, 4, 3, 4]
playing = [2, 2, 1, 1, 2, 3, 2]
watching_tv = [2, 1, 2, 2, 1, 1, 1]
sleeping = [5, 5, 6, 5, 6, 5, 5]
labels = ['Studying', 'Playing', 'Watching TV', 'Sleeping']
colors = ['skyblue', 'lightgreen', 'gold', 'lightcoral']
plt.figure(figsize=(10,6))
plt.stackplot(days, studying, playing, watching_tv, sleeping,
labels=labels, colors=colors,alpha=1)
plt.legend(loc='upper right') # Location of the legend
plt.title('Weekly Activity Tracker')
plt.xlabel('Day')
plt.ylabel('Hours')
plt.grid(True)
plt.show()
