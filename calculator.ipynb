# %%
#calculator using id and elif
first_number=int(input("enter the first number:"))
second_number=int(input("the the second number:"))
operation=str(input("enter your operation:"))
if operation=='+':
    print(first_number + second_number)
elif operation=='-':
    print(first_number-second_number)
elif operation=='*':
    print( first_number*second_number)
elif operation=='/':
    if second_number==0:
        print("we can not devide by zero")
    else:
        print(first_number/second_number)

# %%
#calculator using match case
try:
    a=int(input("enter the value of a:"))
    b=int(input("enter the value of b:"))
    print("enter your operation +,-,*,/:")
    o=input("enter your operation:")
    match o:
     case "+":
         print(F"sum is {a+b}")
     case "-":
         print(F"sub is {a-b}")
     case "*":
         print(F"mul is {a*b}")
     case "/":
         if b==0:
             print("we can not devide by zero")
         else:
             print(f"div is {a/b}")
        # print(F"sum is {a/b}")
except exception as e:
    print("entrt the valid value of a and b")
# Out:
# enter the value of a: 2
# enter the value of b: 3
# enter your operation +,-,*,/:
# enter your operation: +
# sum is 5
