# %%
import pandas as pd

# %%
s1=pd.Series([10,7,8,8,5])
print(s1)
print(type(s1))
# Out:
# 0    10
# 1     7
# 2     8
# 3     8
# 4     5
# dtype: int64
# <class 'pandas.core.series.Series'>

# %%
s2=pd.Series([10,7,8,8,5],index=["a","b","c","d","e"])
print(s2)
# Out:
# a    10
# b     7
# c     8
# d     8
# e     5
# dtype: int64

# %%
s3={
    "name":["samay","ommu","ravi","biswo"],
    "marks":[40,46,49,48]}
s4=pd.DataFrame(s3)
print(s4)
# Out:
#     name  marks
# 0  samay     40
# 1   ommu     46
# 2   ravi     49
# 3  biswo     48

# %%
data = {
    "name": ["Alice", "Bob", "Charlie"],
    "age": [25, 30, 35],
    "city": ["Delhi", "Mumbai", "Bangalore"]
}

df = pd.DataFrame(data)
print(df)
df.index = ["a", "b", "c"]
df.columns = ["Name", "Age", "City"]
# Out:
#       name  age       city
# 0    Alice   25      Delhi
# 1      Bob   30     Mumbai
# 2  Charlie   35  Bangalore
