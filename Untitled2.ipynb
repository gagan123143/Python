# %%
import pandas as pd
data = [
["Alice", 25],
["Bob", 30],
["Charlie", 35]
]
df=pd.DataFrame(data,columns=["name","mark"])

# %%
df
# Out:
#       name  mark
# 0    Alice    25
# 1      Bob    30
# 2  Charlie    35

# %%
data = {
"Name": ["Alice", "Bob", "Charlie"],
"Age": [25, 30, 35]
}
df2=pd.DataFrame(data)
df2
# Out:
#       Name  Age
# 0    Alice   25
# 1      Bob   30
# 2  Charlie   35
